# %% [markdown]
# # Part 1 - Model Training
#
# This code looks at creating a linear regression model, looking at reproducing Moore's Law.

# %%
# We first verify the correct version of TF installed
# !pip install -q tensorflow-gpu==2.1.0

try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
print(tf.__version__)
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# 2.1.0

# %%
# Obtaining the data - this is done using the wget method, to obtain the data from the instructor's github repo

# !wget https://raw.githubusercontent.com/lazyprogrammer/machine_learning_examples/master/tf2.0/moore.csv

# We then load the data, and split it into train data and labels, and reshape X to have it in the format accepted by Keras/Tensorflow
# We also check the shapes of X and y, to make sure they follow the required format

data = pd.read_csv('moore.csv', header=None).values
X = data[:,0]
print(X.shape)
X.reshape(-1,1)
print(X.shape)
y = data[:,1]
print(y.shape)
# Out:
# --2020-02-10 18:14:44--  https://raw.githubusercontent.com/lazyprogrammer/machine_learning_examples/master/tf2.0/moore.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2302 (2.2K) [text/plain]
# Saving to: ‘moore.csv.3’
#
# moore.csv.3         100%[===================>]   2.25K  --.-KB/s    in 0s
#
# 2020-02-10 18:14:44 (83.5 MB/s) - ‘moore.csv.3’ saved [2302/2302]
#
# (162,)
# (162,)
# (162,)

# %%
# To further check the data, we plot it
# In a scatter plot, it is exponential. If we take the log of y, the data follows a linear pattern.

plt.scatter(X,y)

plt.figure()
y_log = np.log(y)
plt.scatter(X,y_log)

# %%
# Currently, X is the year. For creating the model, we need to center X around 0
# This is done so that the values are not too large, as currently the values are large 
# This can either be done by scaling, but this means that latter the data would need to be reverse transformed.
# Scaluing would also mean that a step increase in X would no longer be equivalent to a 1 year increase in real terms.

X = X - X.mean()

# %%
# Now, the Tensofrlow model is created. An input and dense layer are created.
# For linear regression, there is no activation function.
# Two models are created:
# - the first one uses the adam optimizer
# - the second one uses an optimizer object, with learning rate = 0.001, and momentum = 0.9 (this allows the user more control)
# The mean squared error (mse) is used as a loss function
# A learning rate scheduler is also created, to scale the learning rate based on the training epoch.

model_1 = tf.keras.models.Sequential(
    [
     tf.keras.layers.Input(shape=(1,)),
     tf.keras.layers.Dense(1)
    ]
)

model_1.compile(optimizer = 'adam', loss='mse')

model_2 = tf.keras.models.Sequential(
    [
     tf.keras.layers.Input(shape=(1,)),
     tf.keras.layers.Dense(1)
    ]
)

model_2.compile(optimizer = tf.keras.optimizers.SGD(0.001, 0.9), loss='mse')

def schedule(epoch, learning_rate):
  """This function schedules a variable learning rate based on the epoch number

  :param epoch: The current training epoch
  :type epoch: float
  :return: A value for the learning rate
  :rtype: float
  """
  if epoch >= 50:
    return 0.0001
  else:
    return 0.001

scheduler = tf.keras.callbacks.LearningRateScheduler(schedule)

r1 = model_1.fit(X, y_log, epochs = 200, callbacks=[scheduler])
r2 = model_2.fit(X, y_log, epochs = 200, callbacks=[scheduler])
# Out:
# Train on 162 samples
# Epoch 1/200
# 162/162 [==============================] - 0s 1ms/sample - loss: 400.4024
# Epoch 2/200
# 162/162 [==============================] - 0s 86us/sample - loss: 398.7501
# Epoch 3/200
# 162/162 [==============================] - 0s 79us/sample - loss: 397.0952
# Epoch 4/200
# 162/162 [==============================] - 0s 83us/sample - loss: 395.4065
# Epoch 5/200
# 162/162 [==============================] - 0s 87us/sample - loss: 393.7750
# Epoch 6/200
# 162/162 [==============================] - 0s 85us/sample - loss: 392.1952
# Epoch 7/200
# 162/162 [==============================] - 0s 102us/sample - loss: 390.6614
# Epoch 8/200
# 162/162 [==============================] - 0s 102us/sample - loss: 389.1940
# Epoch 9/200
# 162/162 [==============================] - 0s 95us/sample - loss: 387.9170
# Epoch 10/200
# 162/162 [==============================] - 0s 101us/sample - loss: 386.3734
# Epoch 11/200
# 162/162 [==============================] - 0s 97us/sample - loss: 384.9738
# Epoch 12/200
# 162/162 [==============================] - 0s 78us/sample - loss: 383.5394
# Epoch 13/200
# 162/162 [==============================] - 0s 83us/sample - loss: 382.1588
# Epoch 14/200
# 162/162 [==============================] - 0s 101us/sample - loss: 380.6612
# Epoch 15/200
# 162/162 [==============================] - 0s 111us/sample - loss: 379.1933
# Epoch 16/200
# 162/162 [==============================] - 0s 88us/sample - loss: 377.8388
# Epoch 17/200
# 162/162 [==============================] - 0s 89us/sample - loss: 376.5677
# Epoch 18/200
# 162/162 [==============================] - 0s 92us/sample - loss: 375.3811
# Epoch 19/200
# 162/162 [==============================] - 0s 79us/sample - loss: 374.1573
# Epoch 20/200
# 162/162 [==============================] - 0s 80us/sample - loss: 372.9741
# Epoch 21/200
# 162/162 [==============================] - 0s 79us/sample - loss: 371.6617
# Epoch 22/200
# 162/162 [==============================] - 0s 79us/sample - loss: 370.2675
# Epoch 23/200
# 162/162 [==============================] - 0s 91us/sample - loss: 368.8418
# Epoch 24/200
# 162/162 [==============================] - 0s 88us/sample - loss: 367.5138
# Epoch 25/200
# 162/162 [==============================] - 0s 83us/sample - loss: 366.3590
# Epoch 26/200
# 162/162 [==============================] - 0s 104us/sample - loss: 365.1278
# Epoch 27/200
# 162/162 [==============================] - 0s 118us/sample - loss: 364.0415
# Epoch 28/200
# 162/162 [==============================] - 0s 91us/sample - loss: 362.9386
# Epoch 29/200
# 162/162 [==============================] - 0s 99us/sample - loss: 361.9340
# Epoch 30/200
# 162/162 [==============================] - 0s 117us/sample - loss: 361.0597
# Epoch 31/200
# 162/162 [==============================] - 0s 135us/sample - loss: 360.1545
# Epoch 32/200
# 162/162 [==============================] - 0s 134us/sample - loss: 359.2125
# Epoch 33/200
# 162/162 [==============================] - 0s 99us/sample - loss: 358.2444
# Epoch 34/200
# 162/162 [==============================] - 0s 90us/sample - loss: 357.1609
# Epoch 35/200
# 162/162 [==============================] - 0s 99us/sample - loss: 356.0580
# Epoch 36/200
# 162/162 [==============================] - 0s 99us/sample - loss: 354.9183
# Epoch 37/200
# 162/162 [==============================] - 0s 102us/sample - loss: 353.7734
# Epoch 38/200
# 162/162 [==============================] - 0s 90us/sample - loss: 352.5157
# Epoch 39/200
# 162/162 [==============================] - 0s 98us/sample - loss: 351.4848
# Epoch 40/200
# 162/162 [==============================] - 0s 87us/sample - loss: 350.4446
# Epoch 41/200
# 162/162 [==============================] - 0s 95us/sample - loss: 349.3670
# Epoch 42/200
# 162/162 [==============================] - 0s 103us/sample - loss: 348.3272
# Epoch 43/200
# 162/162 [==============================] - 0s 107us/sample - loss: 347.3582
# Epoch 44/200
# 162/162 [==============================] - 0s 88us/sample - loss: 346.4583
# Epoch 45/200
# 162/162 [==============================] - 0s 81us/sample - loss: 345.4402
# Epoch 46/200
# 162/162 [==============================] - 0s 95us/sample - loss: 344.6037
# Epoch 47/200
# 162/162 [==============================] - 0s 131us/sample - loss: 343.7878
# Epoch 48/200
# 162/162 [==============================] - 0s 108us/sample - loss: 342.9982
# Epoch 49/200
# 162/162 [==============================] - 0s 93us/sample - loss: 342.0730
# Epoch 50/200
# 162/162 [==============================] - 0s 79us/sample - loss: 341.2587
# Epoch 51/200
# 162/162 [==============================] - 0s 89us/sample - loss: 340.6317
# Epoch 52/200
# 162/162 [==============================] - 0s 87us/sample - loss: 340.5426
# Epoch 53/200
# 162/162 [==============================] - 0s 88us/sample - loss: 340.4548
# Epoch 54/200
# 162/162 [==============================] - 0s 89us/sample - loss: 340.3572
# Epoch 55/200
# 162/162 [==============================] - 0s 78us/sample - loss: 340.2559
# Epoch 56/200
# 162/162 [==============================] - 0s 85us/sample - loss: 340.1499
# Epoch 57/200
# 162/162 [==============================] - 0s 88us/sample - loss: 340.0444
# Epoch 58/200
# 162/162 [==============================] - 0s 87us/sample - loss: 339.9529
# Epoch 59/200
# 162/162 [==============================] - 0s 95us/sample - loss: 339.8606
# Epoch 60/200
# 162/162 [==============================] - 0s 82us/sample - loss: 339.7883
# Epoch 61/200
# 162/162 [==============================] - 0s 109us/sample - loss: 339.7140
# Epoch 62/200
# 162/162 [==============================] - 0s 89us/sample - loss: 339.6349
# Epoch 63/200
# 162/162 [==============================] - 0s 95us/sample - loss: 339.5467
# Epoch 64/200
# 162/162 [==============================] - 0s 98us/sample - loss: 339.4558
# Epoch 65/200
# 162/162 [==============================] - 0s 127us/sample - loss: 339.3743
# Epoch 66/200
# 162/162 [==============================] - 0s 100us/sample - loss: 339.2853
# Epoch 67/200
# 162/162 [==============================] - 0s 90us/sample - loss: 339.1944
# Epoch 68/200
# 162/162 [==============================] - 0s 85us/sample - loss: 339.1052
# Epoch 69/200
# 162/162 [==============================] - 0s 90us/sample - loss: 339.0261
# Epoch 70/200
# 162/162 [==============================] - 0s 89us/sample - loss: 338.9436
# Epoch 71/200
# 162/162 [==============================] - 0s 99us/sample - loss: 338.8619
# Epoch 72/200
# 162/162 [==============================] - 0s 97us/sample - loss: 338.7747
# Epoch 73/200
# 162/162 [==============================] - 0s 99us/sample - loss: 338.6885
# Epoch 74/200
# 162/162 [==============================] - 0s 90us/sample - loss: 338.6080
# Epoch 75/200
# 162/162 [==============================] - 0s 92us/sample - loss: 338.5318
# Epoch 76/200
# 162/162 [==============================] - 0s 83us/sample - loss: 338.4416
# Epoch 77/200
# 162/162 [==============================] - 0s 81us/sample - loss: 338.3554
# Epoch 78/200
# 162/162 [==============================] - 0s 86us/sample - loss: 338.2648
# Epoch 79/200
# 162/162 [==============================] - 0s 82us/sample - loss: 338.1793
# Epoch 80/200
# 162/162 [==============================] - 0s 89us/sample - loss: 338.0838
# Epoch 81/200
# 162/162 [==============================] - 0s 79us/sample - loss: 337.9900
# Epoch 82/200
# 162/162 [==============================] - 0s 80us/sample - loss: 337.8881
# Epoch 83/200
# 162/162 [==============================] - 0s 80us/sample - loss: 337.7880
# Epoch 84/200
# 162/162 [==============================] - 0s 82us/sample - loss: 337.6967
# Epoch 85/200
# 162/162 [==============================] - 0s 75us/sample - loss: 337.6083
# Epoch 86/200
# 162/162 [==============================] - 0s 82us/sample - loss: 337.5279
# Epoch 87/200
# 162/162 [==============================] - 0s 116us/sample - loss: 337.4376
# Epoch 88/200
# 162/162 [==============================] - 0s 87us/sample - loss: 337.3553
# Epoch 89/200
# 162/162 [==============================] - 0s 99us/sample - loss: 337.2730
# Epoch 90/200
# 162/162 [==============================] - 0s 118us/sample - loss: 337.1960
# Epoch 91/200
# 162/162 [==============================] - 0s 114us/sample - loss: 337.1162
# Epoch 92/200
# 162/162 [==============================] - 0s 102us/sample - loss: 337.0145
# Epoch 93/200
# 162/162 [==============================] - 0s 95us/sample - loss: 336.9366
# Epoch 94/200
# 162/162 [==============================] - 0s 96us/sample - loss: 336.8654
# Epoch 95/200
# 162/162 [==============================] - 0s 87us/sample - loss: 336.7847
# Epoch 96/200
# 162/162 [==============================] - 0s 82us/sample - loss: 336.7048
# Epoch 97/200
# 162/162 [==============================] - 0s 86us/sample - loss: 336.6079
# Epoch 98/200
# 162/162 [==============================] - 0s 97us/sample - loss: 336.5225
# Epoch 99/200
# 162/162 [==============================] - 0s 110us/sample - loss: 336.4169
# Epoch 100/200
# 162/162 [==============================] - 0s 85us/sample - loss: 336.3259
# Epoch 101/200
# 162/162 [==============================] - 0s 87us/sample - loss: 336.2378
# Epoch 102/200
# 162/162 [==============================] - 0s 101us/sample - loss: 336.1561
# Epoch 103/200
# 162/162 [==============================] - 0s 85us/sample - loss: 336.0843
# Epoch 104/200
# 162/162 [==============================] - 0s 84us/sample - loss: 336.0049
# Epoch 105/200
# 162/162 [==============================] - 0s 98us/sample - loss: 335.9230
# Epoch 106/200
# 162/162 [==============================] - 0s 109us/sample - loss: 335.8438
# Epoch 107/200
# 162/162 [==============================] - 0s 111us/sample - loss: 335.7438
# Epoch 108/200
# 162/162 [==============================] - 0s 122us/sample - loss: 335.6562
# Epoch 109/200
# 162/162 [==============================] - 0s 87us/sample - loss: 335.5705
# Epoch 110/200
# 162/162 [==============================] - 0s 85us/sample - loss: 335.4763
# Epoch 111/200
# 162/162 [==============================] - 0s 79us/sample - loss: 335.3876
# Epoch 112/200
# 162/162 [==============================] - 0s 78us/sample - loss: 335.2991
# Epoch 113/200
# 162/162 [==============================] - 0s 81us/sample - loss: 335.2115
# Epoch 114/200
# 162/162 [==============================] - 0s 84us/sample - loss: 335.1316
# Epoch 115/200
# 162/162 [==============================] - 0s 79us/sample - loss: 335.0534
# Epoch 116/200
# 162/162 [==============================] - 0s 80us/sample - loss: 334.9784
# Epoch 117/200
# 162/162 [==============================] - 0s 104us/sample - loss: 334.8949
# Epoch 118/200
# 162/162 [==============================] - 0s 99us/sample - loss: 334.8170
# Epoch 119/200
# 162/162 [==============================] - 0s 108us/sample - loss: 334.7353
# Epoch 120/200
# 162/162 [==============================] - 0s 94us/sample - loss: 334.6424
# Epoch 121/200
# 162/162 [==============================] - 0s 115us/sample - loss: 334.5616
# Epoch 122/200
# 162/162 [==============================] - 0s 116us/sample - loss: 334.4889
# Epoch 123/200
# 162/162 [==============================] - 0s 111us/sample - loss: 334.4119
# Epoch 124/200
# 162/162 [==============================] - 0s 103us/sample - loss: 334.3268
# Epoch 125/200
# 162/162 [==============================] - 0s 90us/sample - loss: 334.2315
# Epoch 126/200
# 162/162 [==============================] - 0s 88us/sample - loss: 334.1429
# Epoch 127/200
# 162/162 [==============================] - 0s 89us/sample - loss: 334.0478
# Epoch 128/200
# 162/162 [==============================] - 0s 108us/sample - loss: 333.9570
# Epoch 129/200
# 162/162 [==============================] - 0s 95us/sample - loss: 333.8652
# Epoch 130/200
# 162/162 [==============================] - 0s 102us/sample - loss: 333.7731
# Epoch 131/200
# 162/162 [==============================] - 0s 104us/sample - loss: 333.6735
# Epoch 132/200
# 162/162 [==============================] - 0s 98us/sample - loss: 333.5875
# Epoch 133/200
# 162/162 [==============================] - 0s 89us/sample - loss: 333.4964
# Epoch 134/200
# 162/162 [==============================] - 0s 95us/sample - loss: 333.3976
# Epoch 135/200
# 162/162 [==============================] - 0s 95us/sample - loss: 333.3023
# Epoch 136/200
# 162/162 [==============================] - 0s 103us/sample - loss: 333.2104
# Epoch 137/200
# 162/162 [==============================] - 0s 84us/sample - loss: 333.1325
# Epoch 138/200
# 162/162 [==============================] - 0s 83us/sample - loss: 333.0404
# Epoch 139/200
# 162/162 [==============================] - 0s 99us/sample - loss: 332.9434
# Epoch 140/200
# 162/162 [==============================] - 0s 102us/sample - loss: 332.8460
# Epoch 141/200
# 162/162 [==============================] - 0s 147us/sample - loss: 332.7617
# Epoch 142/200
# 162/162 [==============================] - 0s 119us/sample - loss: 332.6846
# Epoch 143/200
# 162/162 [==============================] - 0s 96us/sample - loss: 332.6062
# Epoch 144/200
# 162/162 [==============================] - 0s 93us/sample - loss: 332.5229
# Epoch 145/200
# 162/162 [==============================] - 0s 135us/sample - loss: 332.4487
# Epoch 146/200
# 162/162 [==============================] - 0s 97us/sample - loss: 332.3712
# Epoch 147/200
# 162/162 [==============================] - 0s 98us/sample - loss: 332.3003
# Epoch 148/200
# 162/162 [==============================] - 0s 93us/sample - loss: 332.2248
# Epoch 149/200
# 162/162 [==============================] - 0s 99us/sample - loss: 332.1347
# Epoch 150/200
# 162/162 [==============================] - 0s 95us/sample - loss: 332.0563
# Epoch 151/200
# 162/162 [==============================] - 0s 138us/sample - loss: 331.9744
# Epoch 152/200
# 162/162 [==============================] - 0s 87us/sample - loss: 331.8995
# Epoch 153/200
# 162/162 [==============================] - 0s 96us/sample - loss: 331.8173
# Epoch 154/200
# 162/162 [==============================] - 0s 117us/sample - loss: 331.7314
# Epoch 155/200
# 162/162 [==============================] - 0s 98us/sample - loss: 331.6318
# Epoch 156/200
# 162/162 [==============================] - 0s 85us/sample - loss: 331.5369
# Epoch 157/200
# 162/162 [==============================] - 0s 104us/sample - loss: 331.4609
# Epoch 158/200
# 162/162 [==============================] - 0s 101us/sample - loss: 331.3775
# Epoch 159/200
# 162/162 [==============================] - 0s 133us/sample - loss: 331.3020
# Epoch 160/200
# 162/162 [==============================] - 0s 122us/sample - loss: 331.2318
# Epoch 161/200
# 162/162 [==============================] - 0s 128us/sample - loss: 331.1689
# Epoch 162/200
# 162/162 [==============================] - 0s 121us/sample - loss: 331.1099
# Epoch 163/200
# 162/162 [==============================] - 0s 89us/sample - loss: 331.0394
# Epoch 164/200
# 162/162 [==============================] - 0s 112us/sample - loss: 330.9591
# Epoch 165/200
# 162/162 [==============================] - 0s 97us/sample - loss: 330.8759
# Epoch 166/200
# 162/162 [==============================] - 0s 95us/sample - loss: 330.7943
# Epoch 167/200
# 162/162 [==============================] - 0s 83us/sample - loss: 330.7104
# Epoch 168/200
# 162/162 [==============================] - 0s 74us/sample - loss: 330.6391
# Epoch 169/200
# 162/162 [==============================] - 0s 90us/sample - loss: 330.5628
# Epoch 170/200
# 162/162 [==============================] - 0s 85us/sample - loss: 330.4885
# Epoch 171/200
# 162/162 [==============================] - 0s 97us/sample - loss: 330.4193
# Epoch 172/200
# 162/162 [==============================] - 0s 92us/sample - loss: 330.3431
# Epoch 173/200
# 162/162 [==============================] - 0s 105us/sample - loss: 330.2648
# Epoch 174/200
# 162/162 [==============================] - 0s 90us/sample - loss: 330.1793
# Epoch 175/200
# 162/162 [==============================] - 0s 88us/sample - loss: 330.0985
# Epoch 176/200
# 162/162 [==============================] - 0s 115us/sample - loss: 330.0154
# Epoch 177/200
# 162/162 [==============================] - 0s 105us/sample - loss: 329.9254
# Epoch 178/200
# 162/162 [==============================] - 0s 83us/sample - loss: 329.8373
# Epoch 179/200
# 162/162 [==============================] - 0s 95us/sample - loss: 329.7450
# Epoch 180/200
# 162/162 [==============================] - 0s 96us/sample - loss: 329.6572
# Epoch 181/200
# 162/162 [==============================] - 0s 86us/sample - loss: 329.5844
# Epoch 182/200
# 162/162 [==============================] - 0s 78us/sample - loss: 329.4979
# Epoch 183/200
# 162/162 [==============================] - 0s 80us/sample - loss: 329.4230
# Epoch 184/200
# 162/162 [==============================] - 0s 76us/sample - loss: 329.3392
# Epoch 185/200
# 162/162 [==============================] - 0s 79us/sample - loss: 329.2677
# Epoch 186/200
# 162/162 [==============================] - 0s 82us/sample - loss: 329.2079
# Epoch 187/200
# 162/162 [==============================] - 0s 97us/sample - loss: 329.1303
# Epoch 188/200
# 162/162 [==============================] - 0s 82us/sample - loss: 329.0469
# Epoch 189/200
# 162/162 [==============================] - 0s 82us/sample - loss: 328.9661
# Epoch 190/200
# 162/162 [==============================] - 0s 110us/sample - loss: 328.8826
# Epoch 191/200
# 162/162 [==============================] - 0s 95us/sample - loss: 328.8103
# Epoch 192/200
# 162/162 [==============================] - 0s 79us/sample - loss: 328.7433
# Epoch 193/200
# 162/162 [==============================] - 0s 102us/sample - loss: 328.6590
# Epoch 194/200
# 162/162 [==============================] - 0s 90us/sample - loss: 328.5818
# Epoch 195/200
# 162/162 [==============================] - 0s 132us/sample - loss: 328.5042
# Epoch 196/200
# 162/162 [==============================] - 0s 81us/sample - loss: 328.4147
# Epoch 197/200
# 162/162 [==============================] - 0s 82us/sample - loss: 328.3237
# Epoch 198/200
# 162/162 [==============================] - 0s 103us/sample - loss: 328.2496
# Epoch 199/200
# 162/162 [==============================] - 0s 100us/sample - loss: 328.1799
# Epoch 200/200
# 162/162 [==============================] - 0s 84us/sample - loss: 328.1108
# Train on 162 samples
# Epoch 1/200
# 162/162 [==============================] - 0s 922us/sample - loss: 327.2746
# Epoch 2/200
# 162/162 [==============================] - 0s 98us/sample - loss: 304.5200
# Epoch 3/200
# 162/162 [==============================] - 0s 78us/sample - loss: 239.5564
# Epoch 4/200
# 162/162 [==============================] - 0s 86us/sample - loss: 210.4661
# Epoch 5/200
# 162/162 [==============================] - 0s 88us/sample - loss: 171.3969
# Epoch 6/200
# 162/162 [==============================] - 0s 93us/sample - loss: 116.6509
# Epoch 7/200
# 162/162 [==============================] - 0s 86us/sample - loss: 105.2207
# Epoch 8/200
# 162/162 [==============================] - 0s 88us/sample - loss: 68.2278
# Epoch 9/200
# 162/162 [==============================] - 0s 90us/sample - loss: 50.5971
# Epoch 10/200
# 162/162 [==============================] - 0s 110us/sample - loss: 44.5213
# Epoch 11/200
# 162/162 [==============================] - 0s 107us/sample - loss: 28.9057
# Epoch 12/200
# 162/162 [==============================] - 0s 101us/sample - loss: 22.5656
# Epoch 13/200
# 162/162 [==============================] - 0s 91us/sample - loss: 17.7572
# Epoch 14/200
# 162/162 [==============================] - 0s 87us/sample - loss: 12.7779
# Epoch 15/200
# 162/162 [==============================] - 0s 84us/sample - loss: 14.3725
# Epoch 16/200
# 162/162 [==============================] - 0s 86us/sample - loss: 12.2067
# Epoch 17/200
# 162/162 [==============================] - 0s 97us/sample - loss: 9.2557
# Epoch 18/200
# 162/162 [==============================] - 0s 114us/sample - loss: 5.1294
# Epoch 19/200
# 162/162 [==============================] - 0s 86us/sample - loss: 3.4036
# Epoch 20/200
# 162/162 [==============================] - 0s 100us/sample - loss: 3.7922
# Epoch 21/200
# 162/162 [==============================] - 0s 82us/sample - loss: 3.0335
# Epoch 22/200
# 162/162 [==============================] - 0s 88us/sample - loss: 2.2300
# Epoch 23/200
# 162/162 [==============================] - 0s 104us/sample - loss: 1.7561
# Epoch 24/200
# 162/162 [==============================] - 0s 87us/sample - loss: 1.4093
# Epoch 25/200
# 162/162 [==============================] - 0s 99us/sample - loss: 1.2172
# Epoch 26/200
# 162/162 [==============================] - 0s 127us/sample - loss: 1.0930
# Epoch 27/200
# 162/162 [==============================] - 0s 87us/sample - loss: 1.0386
# Epoch 28/200
# 162/162 [==============================] - 0s 116us/sample - loss: 1.0151
# Epoch 29/200
# 162/162 [==============================] - 0s 100us/sample - loss: 0.9650
# Epoch 30/200
# 162/162 [==============================] - 0s 90us/sample - loss: 0.9643
# Epoch 31/200
# 162/162 [==============================] - 0s 81us/sample - loss: 0.9470
# Epoch 32/200
# 162/162 [==============================] - 0s 79us/sample - loss: 0.9238
# Epoch 33/200
# 162/162 [==============================] - 0s 84us/sample - loss: 0.9482
# Epoch 34/200
# 162/162 [==============================] - 0s 95us/sample - loss: 0.9344
# Epoch 35/200
# 162/162 [==============================] - 0s 95us/sample - loss: 0.9549
# Epoch 36/200
# 162/162 [==============================] - 0s 93us/sample - loss: 1.0686
# Epoch 37/200
# 162/162 [==============================] - 0s 115us/sample - loss: 0.9524
# Epoch 38/200
# 162/162 [==============================] - 0s 100us/sample - loss: 0.9999
# Epoch 39/200
# 162/162 [==============================] - 0s 102us/sample - loss: 0.9217
# Epoch 40/200
# 162/162 [==============================] - 0s 88us/sample - loss: 0.8757
# Epoch 41/200
# 162/162 [==============================] - 0s 81us/sample - loss: 0.8798
# Epoch 42/200
# 162/162 [==============================] - 0s 79us/sample - loss: 1.2050
# Epoch 43/200
# 162/162 [==============================] - 0s 115us/sample - loss: 0.9854
# Epoch 44/200
# 162/162 [==============================] - 0s 84us/sample - loss: 1.0611
# Epoch 45/200
# 162/162 [==============================] - 0s 118us/sample - loss: 1.2950
# Epoch 46/200
# 162/162 [==============================] - 0s 97us/sample - loss: 1.0036
# Epoch 47/200
# 162/162 [==============================] - 0s 100us/sample - loss: 0.9893
# Epoch 48/200
# 162/162 [==============================] - 0s 80us/sample - loss: 0.9195
# Epoch 49/200
# 162/162 [==============================] - 0s 100us/sample - loss: 0.8914
# Epoch 50/200
# 162/162 [==============================] - 0s 109us/sample - loss: 0.9268
# Epoch 51/200
# 162/162 [==============================] - 0s 125us/sample - loss: 1.3954
# Epoch 52/200
# 162/162 [==============================] - 0s 101us/sample - loss: 1.5797
# Epoch 53/200
# 162/162 [==============================] - 0s 91us/sample - loss: 0.9575
# Epoch 54/200
# 162/162 [==============================] - 0s 108us/sample - loss: 0.9893
# Epoch 55/200
# 162/162 [==============================] - 0s 114us/sample - loss: 0.9310
# Epoch 56/200
# 162/162 [==============================] - 0s 96us/sample - loss: 0.8908
# Epoch 57/200
# 162/162 [==============================] - 0s 91us/sample - loss: 0.9238
# Epoch 58/200
# 162/162 [==============================] - 0s 84us/sample - loss: 0.8908
# Epoch 59/200
# 162/162 [==============================] - 0s 94us/sample - loss: 0.8969
# Epoch 60/200
# 162/162 [==============================] - 0s 91us/sample - loss: 0.9077
# Epoch 61/200
# 162/162 [==============================] - 0s 91us/sample - loss: 0.8681
# Epoch 62/200
# 162/162 [==============================] - 0s 79us/sample - loss: 0.8981
# Epoch 63/200
# 162/162 [==============================] - 0s 80us/sample - loss: 0.8946
# Epoch 64/200
# 162/162 [==============================] - 0s 84us/sample - loss: 0.8756
# Epoch 65/200
# 162/162 [==============================] - 0s 92us/sample - loss: 0.8708
# Epoch 66/200
# 162/162 [==============================] - 0s 118us/sample - loss: 0.8761
# Epoch 67/200
# 162/162 [==============================] - 0s 98us/sample - loss: 0.8690
# Epoch 68/200
# 162/162 [==============================] - 0s 93us/sample - loss: 0.8788
# Epoch 69/200
# 162/162 [==============================] - 0s 91us/sample - loss: 0.8767
# Epoch 70/200
# 162/162 [==============================] - 0s 85us/sample - loss: 0.8723
# Epoch 71/200
# 162/162 [==============================] - 0s 93us/sample - loss: 0.8717
# Epoch 72/200
# 162/162 [==============================] - 0s 84us/sample - loss: 0.8705
# Epoch 73/200
# 162/162 [==============================] - 0s 99us/sample - loss: 0.8729
# Epoch 74/200
# 162/162 [==============================] - 0s 87us/sample - loss: 0.8824
# Epoch 75/200
# 162/162 [==============================] - 0s 76us/sample - loss: 0.8809
# Epoch 76/200
# 162/162 [==============================] - 0s 83us/sample - loss: 0.8691
# Epoch 77/200
# 162/162 [==============================] - 0s 91us/sample - loss: 0.8936
# Epoch 78/200
# 162/162 [==============================] - 0s 102us/sample - loss: 0.9043
# Epoch 79/200
# 162/162 [==============================] - 0s 115us/sample - loss: 0.8772
# Epoch 80/200
# 162/162 [==============================] - 0s 89us/sample - loss: 0.8740
# Epoch 81/200
# 162/162 [==============================] - 0s 91us/sample - loss: 0.8880
# Epoch 82/200
# 162/162 [==============================] - 0s 101us/sample - loss: 0.8836
# Epoch 83/200
# 162/162 [==============================] - 0s 95us/sample - loss: 0.8739
# Epoch 84/200
# 162/162 [==============================] - 0s 119us/sample - loss: 0.8719
# Epoch 85/200
# 162/162 [==============================] - 0s 116us/sample - loss: 0.8787
# Epoch 86/200
# 162/162 [==============================] - 0s 115us/sample - loss: 0.8703
# Epoch 87/200
# 162/162 [==============================] - 0s 102us/sample - loss: 0.8730
# Epoch 88/200
# 162/162 [==============================] - 0s 98us/sample - loss: 0.8718
# Epoch 89/200
# 162/162 [==============================] - 0s 89us/sample - loss: 0.8715
# Epoch 90/200
# 162/162 [==============================] - 0s 86us/sample - loss: 0.8726
# Epoch 91/200
# 162/162 [==============================] - 0s 90us/sample - loss: 0.8716
# Epoch 92/200
# 162/162 [==============================] - 0s 89us/sample - loss: 0.8852
# Epoch 93/200
# 162/162 [==============================] - 0s 93us/sample - loss: 0.8764
# Epoch 94/200
# 162/162 [==============================] - 0s 89us/sample - loss: 0.8697
# Epoch 95/200
# 162/162 [==============================] - 0s 89us/sample - loss: 0.8717
# Epoch 96/200
# 162/162 [==============================] - 0s 88us/sample - loss: 0.8700
# Epoch 97/200
# 162/162 [==============================] - 0s 95us/sample - loss: 0.8707
# Epoch 98/200
# 162/162 [==============================] - 0s 115us/sample - loss: 0.8736
# Epoch 99/200
# 162/162 [==============================] - 0s 88us/sample - loss: 0.8705
# Epoch 100/200
# 162/162 [==============================] - 0s 127us/sample - loss: 0.8745
# Epoch 101/200
# 162/162 [==============================] - 0s 135us/sample - loss: 0.8784
# Epoch 102/200
# 162/162 [==============================] - 0s 121us/sample - loss: 0.8694
# Epoch 103/200
# 162/162 [==============================] - 0s 139us/sample - loss: 0.8712
# Epoch 104/200
# 162/162 [==============================] - 0s 101us/sample - loss: 0.8713
# Epoch 105/200
# 162/162 [==============================] - 0s 87us/sample - loss: 0.8745
# Epoch 106/200
# 162/162 [==============================] - 0s 87us/sample - loss: 0.8749
# Epoch 107/200
# 162/162 [==============================] - 0s 81us/sample - loss: 0.8714
# Epoch 108/200
# 162/162 [==============================] - 0s 105us/sample - loss: 0.8738
# Epoch 109/200
# 162/162 [==============================] - 0s 87us/sample - loss: 0.8746
# Epoch 110/200
# 162/162 [==============================] - 0s 100us/sample - loss: 0.8735
# Epoch 111/200
# 162/162 [==============================] - 0s 91us/sample - loss: 0.8736
# Epoch 112/200
# 162/162 [==============================] - 0s 88us/sample - loss: 0.8742
# Epoch 113/200
# 162/162 [==============================] - 0s 90us/sample - loss: 0.8866
# Epoch 114/200
# 162/162 [==============================] - 0s 100us/sample - loss: 0.8887
# Epoch 115/200
# 162/162 [==============================] - 0s 85us/sample - loss: 0.8771
# Epoch 116/200
# 162/162 [==============================] - 0s 83us/sample - loss: 0.8756
# Epoch 117/200
# 162/162 [==============================] - 0s 103us/sample - loss: 0.8742
# Epoch 118/200
# 162/162 [==============================] - 0s 90us/sample - loss: 0.8708
# Epoch 119/200
# 162/162 [==============================] - 0s 81us/sample - loss: 0.8701
# Epoch 120/200
# 162/162 [==============================] - 0s 91us/sample - loss: 0.8997
# Epoch 121/200
# 162/162 [==============================] - 0s 87us/sample - loss: 0.8756
# Epoch 122/200
# 162/162 [==============================] - 0s 105us/sample - loss: 0.8825
# Epoch 123/200
# 162/162 [==============================] - 0s 96us/sample - loss: 0.9135
# Epoch 124/200
# 162/162 [==============================] - 0s 108us/sample - loss: 0.8931
# Epoch 125/200
# 162/162 [==============================] - 0s 116us/sample - loss: 0.9020
# Epoch 126/200
# 162/162 [==============================] - 0s 115us/sample - loss: 0.9365
# Epoch 127/200
# 162/162 [==============================] - 0s 88us/sample - loss: 0.9240
# Epoch 128/200
# 162/162 [==============================] - 0s 84us/sample - loss: 0.8711
# Epoch 129/200
# 162/162 [==============================] - 0s 103us/sample - loss: 0.8719
# Epoch 130/200
# 162/162 [==============================] - 0s 87us/sample - loss: 0.8751
# Epoch 131/200
# 162/162 [==============================] - 0s 81us/sample - loss: 0.8934
# Epoch 132/200
# 162/162 [==============================] - 0s 81us/sample - loss: 0.9129
# Epoch 133/200
# 162/162 [==============================] - 0s 94us/sample - loss: 0.8935
# Epoch 134/200
# 162/162 [==============================] - 0s 89us/sample - loss: 0.8707
# Epoch 135/200
# 162/162 [==============================] - 0s 85us/sample - loss: 0.8708
# Epoch 136/200
# 162/162 [==============================] - 0s 90us/sample - loss: 0.8746
# Epoch 137/200
# 162/162 [==============================] - 0s 90us/sample - loss: 0.8804
# Epoch 138/200
# 162/162 [==============================] - 0s 92us/sample - loss: 0.8743
# Epoch 139/200
# 162/162 [==============================] - 0s 107us/sample - loss: 0.8736
# Epoch 140/200
# 162/162 [==============================] - 0s 91us/sample - loss: 0.8717
# Epoch 141/200
# 162/162 [==============================] - 0s 105us/sample - loss: 0.8792
# Epoch 142/200
# 162/162 [==============================] - 0s 89us/sample - loss: 0.8802
# Epoch 143/200
# 162/162 [==============================] - 0s 85us/sample - loss: 0.8826
# Epoch 144/200
# 162/162 [==============================] - 0s 88us/sample - loss: 0.8985
# Epoch 145/200
# 162/162 [==============================] - 0s 84us/sample - loss: 0.8882
# Epoch 146/200
# 162/162 [==============================] - 0s 80us/sample - loss: 0.8758
# Epoch 147/200
# 162/162 [==============================] - 0s 78us/sample - loss: 0.8728
# Epoch 148/200
# 162/162 [==============================] - 0s 74us/sample - loss: 0.8726
# Epoch 149/200
# 162/162 [==============================] - 0s 77us/sample - loss: 0.8747
# Epoch 150/200
# 162/162 [==============================] - 0s 86us/sample - loss: 0.8776
# Epoch 151/200
# 162/162 [==============================] - 0s 82us/sample - loss: 0.8735
# Epoch 152/200
# 162/162 [==============================] - 0s 89us/sample - loss: 0.8712
# Epoch 153/200
# 162/162 [==============================] - 0s 84us/sample - loss: 0.8725
# Epoch 154/200
# 162/162 [==============================] - 0s 120us/sample - loss: 0.8741
# Epoch 155/200
# 162/162 [==============================] - 0s 108us/sample - loss: 0.8706
# Epoch 156/200
# 162/162 [==============================] - 0s 93us/sample - loss: 0.8733
# Epoch 157/200
# 162/162 [==============================] - 0s 84us/sample - loss: 0.8869
# Epoch 158/200
# 162/162 [==============================] - 0s 80us/sample - loss: 0.8929
# Epoch 159/200
# 162/162 [==============================] - 0s 79us/sample - loss: 0.8745
# Epoch 160/200
# 162/162 [==============================] - 0s 98us/sample - loss: 0.8805
# Epoch 161/200
# 162/162 [==============================] - 0s 85us/sample - loss: 0.8801
# Epoch 162/200
# 162/162 [==============================] - 0s 100us/sample - loss: 0.8818
# Epoch 163/200
# 162/162 [==============================] - 0s 126us/sample - loss: 0.8798
# Epoch 164/200
# 162/162 [==============================] - 0s 94us/sample - loss: 0.8718
# Epoch 165/200
# 162/162 [==============================] - 0s 101us/sample - loss: 0.8732
# Epoch 166/200
# 162/162 [==============================] - 0s 87us/sample - loss: 0.8759
# Epoch 167/200
# 162/162 [==============================] - 0s 92us/sample - loss: 0.9443
# Epoch 168/200
# 162/162 [==============================] - 0s 83us/sample - loss: 0.9471
# Epoch 169/200
# 162/162 [==============================] - 0s 117us/sample - loss: 0.8828
# Epoch 170/200
# 162/162 [==============================] - 0s 89us/sample - loss: 0.8778
# Epoch 171/200
# 162/162 [==============================] - 0s 95us/sample - loss: 0.8697
# Epoch 172/200
# 162/162 [==============================] - 0s 82us/sample - loss: 0.8750
# Epoch 173/200
# 162/162 [==============================] - 0s 99us/sample - loss: 0.8739
# Epoch 174/200
# 162/162 [==============================] - 0s 99us/sample - loss: 0.8818
# Epoch 175/200
# 162/162 [==============================] - 0s 115us/sample - loss: 0.9352
# Epoch 176/200
# 162/162 [==============================] - 0s 119us/sample - loss: 0.8961
# Epoch 177/200
# 162/162 [==============================] - 0s 111us/sample - loss: 0.8802
# Epoch 178/200
# 162/162 [==============================] - 0s 108us/sample - loss: 0.8889
# Epoch 179/200
# 162/162 [==============================] - 0s 99us/sample - loss: 0.8721
# Epoch 180/200
# 162/162 [==============================] - 0s 113us/sample - loss: 0.8704
# Epoch 181/200
# 162/162 [==============================] - 0s 124us/sample - loss: 0.8888
# Epoch 182/200
# 162/162 [==============================] - 0s 121us/sample - loss: 0.9224
# Epoch 183/200
# 162/162 [==============================] - 0s 101us/sample - loss: 0.8865
# Epoch 184/200
# 162/162 [==============================] - 0s 111us/sample - loss: 0.8783
# Epoch 185/200
# 162/162 [==============================] - 0s 116us/sample - loss: 0.8732
# Epoch 186/200
# 162/162 [==============================] - 0s 123us/sample - loss: 0.8729
# Epoch 187/200
# 162/162 [==============================] - 0s 95us/sample - loss: 0.8705
# Epoch 188/200
# 162/162 [==============================] - 0s 82us/sample - loss: 0.8712
# Epoch 189/200
# 162/162 [==============================] - 0s 81us/sample - loss: 0.8728
# Epoch 190/200
# 162/162 [==============================] - 0s 86us/sample - loss: 0.8738
# Epoch 191/200
# 162/162 [==============================] - 0s 107us/sample - loss: 0.8713
# Epoch 192/200
# 162/162 [==============================] - 0s 93us/sample - loss: 0.8713
# Epoch 193/200
# 162/162 [==============================] - 0s 97us/sample - loss: 0.8737
# Epoch 194/200
# 162/162 [==============================] - 0s 97us/sample - loss: 0.8820
# Epoch 195/200
# 162/162 [==============================] - 0s 104us/sample - loss: 0.8768
# Epoch 196/200
# 162/162 [==============================] - 0s 96us/sample - loss: 0.8763
# Epoch 197/200
# 162/162 [==============================] - 0s 85us/sample - loss: 0.8719
# Epoch 198/200
# 162/162 [==============================] - 0s 90us/sample - loss: 0.8907
# Epoch 199/200
# 162/162 [==============================] - 0s 99us/sample - loss: 0.9019
# Epoch 200/200
# 162/162 [==============================] - 0s 84us/sample - loss: 0.8654

# %%
# To assess how the models perfored, we plot their loss per iteration.

plt.figure()
plt.plot(r1.history['loss'], label='loss adam')
plt.legend()

plt.figure()
plt.plot(r2.history['loss'], label='loss sgd')
plt.legend()

# %%
# To better understand the model, we would like to get the slope of the line, which is related to the doublind rate of the transistor count
# To get the trained weights of the model, we need to access the relevant layer.
# We can observe the input layer is a dummy-layer, keeping track of the input size.
# The '.get_weights' returns two arrays, representing W and b.

print(model_2.layers)
print(model_2.layers[0].get_weights())
print("The Slope:", model_2.layers[0].get_weights()[0][0,0])
# Out:
# [<tensorflow.python.keras.layers.core.Dense object at 0x7f17882de2e8>]
# [array([[0.32843617]], dtype=float32), array([17.76609], dtype=float32)]
# The Slope: 0.32843617

# %%
print("Time to double:", np.log(2) / model_2.layers[0].get_weights()[0][0,0])
# Out:
# Time to double: 2.110447180346571

# %%
# To verify the above calculation, the analytical solution of linear regression is also calculated.

X = np.array(X).flatten()
Y = np.array(y_log)
denominator = X.dot(X) - X.mean() * X.sum()
a = ( X.dot(Y) - Y.mean()*X.sum() ) / denominator
b = ( Y.mean() * X.dot(X) - X.mean() * X.dot(Y) ) / denominator
print(a, b)
print("Time to double:", np.log(2) / a)
# Out:
# 0.341682487387313 17.764939393631764
# Time to double: 2.0286295205239204

# %% [markdown]
# # Part 2 - Making Predictions
#
# This code looks at how the previously trained models can be used in order to generate predictions

# %%
# We first check if the line obtained fits the data
Y_hat = model_2.predict(X).flatten()
plt.scatter(X,y_log)
plt.plot(X,Y_hat,'r')

# %%
# We can also perform a manual calculation

# Get the weights
w, b = model_2.layers[0].get_weights()

# Reshape X because we flattened it again earlier
X = X.reshape(-1, 1)

# (N x 1) x (1 x 1) + (1) --> (N x 1)
Y_hat2 = (X.dot(w) + b).flatten()

# Don't use == for floating points
np.allclose(Y_hat, Y_hat2)
# Out:
# True

# %% [markdown]
# # Part 3 - Making Predictions
#
# This code looks at how the above model can be saved.

# %%
model_2.save('linear_regression.h5')

# %%
# Confirming file stored locally.
# !ls -lh
# Out:
# total 40K
# -rw-r--r-- 1 root root  18K Feb 10 18:26 linear_regression.h5
# -rw-r--r-- 1 root root 2.3K Feb 10 17:16 moore.csv
# -rw-r--r-- 1 root root 2.3K Feb 10 17:17 moore.csv.1
# -rw-r--r-- 1 root root 2.3K Feb 10 17:17 moore.csv.2
# -rw-r--r-- 1 root root 2.3K Feb 10 18:14 moore.csv.3
# drwxr-xr-x 1 root root 4.0K Feb  5 18:37 sample_data

# %%
# Let's load the model and confirm that it still works
# Note: there is a bug in Keras where load/save only works if you DON'T use the Input() layer explicitly
# So, make sure you define the model with ONLY Dense(1, input_shape=(D,))
# At least, until the bug is fixed
# https://github.com/keras-team/keras/issues/10417

model = tf.keras.models.load_model('linear_regression.h5')
print(model.layers)
model.evaluate(X, y_log)
# Out:
# [<tensorflow.python.keras.layers.core.Dense object at 0x7f17705744e0>]
# 162/162 [==============================] - 0s 263us/sample - loss: 0.9029
# 0.9029222660594516
